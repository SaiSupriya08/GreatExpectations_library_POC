# %% [markdown]
# # Initialize a new Expectation Suite by profiling a batch of your data.
# This process helps you avoid writing lots of boilerplate when authoring suites by allowing you to select columns and other factors that you care about and letting a profiler write some candidate expectations for you to adjust.
#
# **Expectation Suite Name**: `profiling_test_snowflake`

# %%
import datetime

import pandas as pd

import great_expectations as gx
import great_expectations.jupyter_ux
from great_expectations.core.batch import BatchRequest
from great_expectations.checkpoint import SimpleCheckpoint
from great_expectations.exceptions import DataContextError

context = gx.get_context()

batch_request = {
    "datasource_name": "my_datasource_new",
    "data_connector_name": "default_inferred_data_connector_name",
    "data_asset_name": "my_schema.employees",
    "limit": 1000,
}

expectation_suite_name = "expectation_test"

validator = context.get_validator(
    batch_request=BatchRequest(**batch_request),
    expectation_suite_name=expectation_suite_name,
)
validator.head(n_rows=5, fetch_all=False)
# Out:
# 2023-02-28T21:49:46+0530 - INFO - Great Expectations logging enabled at 20 level by JupyterUX module.
# 2023-02-28T21:49:46+0530 - INFO - FileDataContext loading zep config
# 2023-02-28T21:49:46+0530 - INFO - GxConfig.parse_yaml() failed with errors - [{'loc': ('xdatasources',), 'msg': 'field required', 'type': 'value_error.missing'}]
# 2023-02-28T21:49:46+0530 - INFO - GxConfig.parse_yaml() returning empty `xdatasources`
# 2023-02-28T21:49:46+0530 - INFO - Loading 'datasources' ->
# {}
# 2023-02-28T21:49:46+0530 - INFO - Loaded 'datasources' ->
# {}
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
#    employee_id first_name  last_name      email phone_number  hire_date  \
# 0        198.0     Donald   OConnell  *********    *********  21-JUN-07
# 1        199.0    Douglas      Grant  *********    *********  13-JAN-08
# 2        200.0   Jennifer     Whalen  *********    *********  17-SEP-03
# 3        201.0    Michael  Hartstein  *********    *********  17-FEB-04
# 4        202.0        Pat        Fay  *********    *********  17-AUG-05
#
#      job_id   salary  manager_id  department_id                  elt_ts  \
# 0  SH_CLERK   2600.0       124.0           50.0 2023-02-06 04:21:14.674
# 1  SH_CLERK   2600.0       124.0           50.0 2023-02-06 04:21:14.674
# 2   AD_ASST   4400.0       101.0           10.0 2023-02-06 04:21:14.674
# 3    MK_MAN  13000.0       100.0           20.0 2023-02-06 04:21:14.674
# 4    MK_REP   6000.0       201.0           20.0 2023-02-06 04:21:14.674
#
#   elt_by      file_name
# 0  local  employees.csv
# 1  local  employees.csv
# 2  local  employees.csv
# 3  local  employees.csv
# 4  local  employees.csv

# %% [markdown]
# # Run the UserConfigurableProfiler
#
# The suites generated here are **not meant to be production suites** -- they are **a starting point to build upon**.
#
# **To get to a production-grade suite, you will definitely want to [edit this
# suite](https://docs.greatexpectations.io/en/latest/guides/how_to_guides/creating_and_editing_expectations/how_to_edit_an_expectation_suite_using_a_disposable_notebook.html?utm_source=notebook&utm_medium=profile_based_expectations)
# after this initial step gets you started on the path towards what you want.**
#
# This is highly configurable depending on your goals.
# You can ignore columns or exclude certain expectations, specify a threshold for creating value set expectations, or even specify semantic types for a given column.
# You can find more information about [how to configure this profiler, including a list of the expectations that it uses, here.](https://docs.greatexpectations.io/en/latest/guides/how_to_guides/creating_and_editing_expectations/how_to_create_an_expectation_suite_with_the_user_configurable_profiler.html)

# %%
result = context.run_profiler_with_dynamic_arguments(
    name="rule_based_profiler", batch_request=batch_request,
)
validator.expectation_suite = result.get_expectation_suite(
    expectation_suite_name=expectation_suite_name
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/great_expectations/data_context/store/tuple_store_backend.py:302, in TupleFilesystemStoreBackend._get(self, key)
#     301 try:
# --> 302     with open(filepath) as infile:
#     303         contents: str = infile.read().rstrip("\n")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/saisupriya/Desktop/OBE/gx_tutorials/great_expectations/profilers/rule_based_profiler.yml'
#
# During handling of the above exception, another exception occurred:
#
# InvalidKeyError                           Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/great_expectations/rule_based_profiler/rule_based_profiler.py:1328, in BaseRuleBasedProfiler.get_profiler(cls, data_context, profiler_store, name, id)
#    1327 try:
# -> 1328     profiler_config: RuleBasedProfilerConfig = profiler_store.get(key=key)
#    1329 except gx_exceptions.InvalidKeyError as exc_ik:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/great_expectations/data_context/store/store.py:170, in Store.get(self, key)
#     169     self._validate_key(key)
# --> 170     value = self._store_backend.get(self.key_to_tuple(key))
#     172 if value:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/great_expectations/data_context/store/_store_backend.py:120, in StoreBackend.get(self, key, **kwargs)
#     119 self._validate_key(key)
# --> 120 value = self._get(key, **kwargs)
#     121 return value
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/great_expectations/data_context/store/tuple_store_backend.py:305, in TupleFilesystemStoreBackend._get(self, key)
#     304 except FileNotFoundError:
# --> 305     raise InvalidKeyError(
#     306         f"Unable to retrieve object from TupleFilesystemStoreBackend with the following Key: {str(filepath)}"
#     307     )
#     309 return contents
#
# InvalidKeyError: Unable to retrieve object from TupleFilesystemStoreBackend with the following Key: /Users/saisupriya/Desktop/OBE/gx_tutorials/great_expectations/profilers/rule_based_profiler.yml
#
# During handling of the above exception, another exception occurred:
#
# ProfilerNotFoundError                     Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 result = context.run_profiler_with_dynamic_arguments(
#       2     name="rule_based_profiler", batch_request=batch_request,
#       3 )
#       4 validator.expectation_suite = result.get_expectation_suite(
#       5     expectation_suite_name=expectation_suite_name
#       6 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/great_expectations/core/usage_statistics/usage_statistics.py:316, in usage_statistics_enabled_method.<locals>.usage_statistics_wrapped_method(*args, **kwargs)
#     313     if args_payload_fn is not None:
#     314         nested_update(event_payload, args_payload_fn(*args, **kwargs))
# --> 316     result = func(*args, **kwargs)
#     317     message["success"] = True
#     318 except Exception:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/great_expectations/data_context/data_context/abstract_data_context.py:3182, in AbstractDataContext.run_profiler_with_dynamic_arguments(***failed resolving arguments***)
#    3179 id = self._resolve_id_and_ge_cloud_id(id=id, ge_cloud_id=ge_cloud_id)
#    3180 del ge_cloud_id
# -> 3182 return self._run_profiler_with_dynamic_arguments(
#    3183     batch_list=batch_list,
#    3184     batch_request=batch_request,
#    3185     name=name,
#    3186     id=id,
#    3187     variables=variables,
#    3188     rules=rules,
#    3189 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/great_expectations/data_context/data_context/abstract_data_context.py:3200, in AbstractDataContext._run_profiler_with_dynamic_arguments(self, batch_list, batch_request, name, id, variables, rules)
#    3191 def _run_profiler_with_dynamic_arguments(
#    3192     self,
#    3193     batch_list: Optional[List[Batch]] = None,
#    (...)
#    3198     rules: Optional[dict] = None,
#    3199 ) -> RuleBasedProfilerResult:
# -> 3200     return RuleBasedProfiler.run_profiler(
#    3201         data_context=self,
#    3202         profiler_store=self.profiler_store,
#    3203         batch_list=batch_list,
#    3204         batch_request=batch_request,
#    3205         name=name,
#    3206         id=id,
#    3207         variables=variables,
#    3208         rules=rules,
#    3209     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/great_expectations/rule_based_profiler/rule_based_profiler.py:1069, in BaseRuleBasedProfiler.run_profiler(cls, data_context, profiler_store, batch_list, batch_request, name, id, variables, rules)
#    1057 @classmethod
#    1058 def run_profiler(
#    1059     cls,
#    (...)
#    1067     rules: Optional[dict] = None,
#    1068 ) -> RuleBasedProfilerResult:
# -> 1069     profiler: RuleBasedProfiler = cls.get_profiler(
#    1070         data_context=data_context,
#    1071         profiler_store=profiler_store,
#    1072         name=name,
#    1073         id=id,
#    1074     )
#    1076     return profiler.run(
#    1077         variables=variables,
#    1078         rules=rules,
#    (...)
#    1085         comment=None,
#    1086     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/great_expectations/rule_based_profiler/rule_based_profiler.py:1335, in BaseRuleBasedProfiler.get_profiler(cls, data_context, profiler_store, name, id)
#    1329 except gx_exceptions.InvalidKeyError as exc_ik:
#    1330     config_id: Union[GXCloudIdentifier, ConfigurationIdentifier] = (
#    1331         key.configuration_key
#    1332         if isinstance(key, ConfigurationIdentifier)
#    1333         else key
#    1334     )
# -> 1335     raise gx_exceptions.ProfilerNotFoundError(
#    1336         message=f'Non-existent Profiler configuration named "{config_id}".\n\nDetails: {exc_ik}'
#    1337     )
#    1339 config: dict = profiler_config.to_json_dict()
#    1340 if name:
#
# ProfilerNotFoundError: Non-existent Profiler configuration named "rule_based_profiler".
#
# Details: Unable to retrieve object from TupleFilesystemStoreBackend with the following Key: /Users/saisupriya/Desktop/OBE/gx_tutorials/great_expectations/profilers/rule_based_profiler.yml

# %% [markdown]
# # Save & review your new Expectation Suite
#
# Let's save the draft expectation suite as a JSON file in the
# `great_expectations/expectations` directory of your project and rebuild the Data
#  Docs site to make it easy to review your new suite.

# %%
print(validator.get_expectation_suite(discard_failed_expectations=False))
validator.save_expectation_suite(discard_failed_expectations=False)

checkpoint_config = {
    "class_name": "SimpleCheckpoint",
    "validations": [
        {
            "batch_request": batch_request,
            "expectation_suite_name": expectation_suite_name,
        }
    ],
}
checkpoint = SimpleCheckpoint(
    f"{validator.active_batch_definition.data_asset_name}_{expectation_suite_name}",
    context,
    **checkpoint_config,
)
checkpoint_result = checkpoint.run()

context.build_data_docs()

validation_result_identifier = checkpoint_result.list_validation_result_identifiers()[0]
context.open_data_docs(resource_identifier=validation_result_identifier)

# %% [markdown]
# ## Next steps
# After you review this initial Expectation Suite in Data Docs you
# should edit this suite to make finer grained adjustments to the expectations.
# This can be done by running `great_expectations suite edit profiling_test_snowflake`.
